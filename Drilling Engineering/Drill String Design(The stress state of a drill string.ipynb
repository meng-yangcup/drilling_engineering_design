# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
L_dp = float(input("Enter length of drill pipe(ft)"))
W_dp = float(input("Enter weight of drill pipe(lbm/ft)"))
L_dc = float(input("Enter length of drill collar(ft)"))
W_dc = float(input("Enter  weight of drill collar(lbm/ft)"))
mud_w = float(input("Enter mud weight(ppg)"))
# Out:
# Enter length of drill pipe(ft)8000
# Enter weight of drill pipe(lbm/ft)18
# Enter length of drill collar(ft)800
# Enter  weight of drill collar(lbm/ft)135
# Enter mud weight(ppg)12

# %%
BF = 1 - (15/65.5)

W_air = L_dp*w_dp + L_dc*w_dc

W_buoyed = W_air*BF

# %%
print(W_buoyed)
# Out:
# 178870.2290076336

# %%
p1 = 0.052*mud_w*L_dp
print("The value of Hydrostatic Pressure at the TOp of Drill collars is",p1,"psi")
depth = np.arange(12000,-1,-2000)
stress = np.arange(-500,501,100)
# Out:
# The value of Hydrostatic Pressure at the TOp of Drill collars is 4992.0 psi

# %%
p2 = 0.052*mud_w*(L_dp+L_dc)
print("The value of hydrostatic at the bottom of the drill collars is",p2,"psi")
# Out:
# The value of hydrostatic at the bottom of the drill collars is 5491.2 psi

# %%
A_dp = (w_dp/490)*144  
print("The value of Cross Sectional Area of drillpipe is",A_dp,"sq. in")
# Out:
# The value of Cross Sectional Area of drillpipe is 4.848979591836735 sq. in

# %%
A_dc = (w_dc/490)*144 
print("The value of Cross Sectional Area of drillcollar is",A_dc,"sq. in")
# Out:
# The value of Cross Sectional Area of drillcollar is 36.734693877551024 sq. in

# %%
d_dp = np.arange(10001,-1,-100)

d_dc = np.arange (12001,10001,-100)

F_dp = 178870.2290076336 - 19.5*d_dp

F_dc = 1201000 - 147*d_dc

print("The value of weight at drillpipe is",F_dp)
print("The value of weight at drillcollar is",F_dc)
# Out:
# The value of weight at drillpipe is [-16149.27099237 -14199.27099237 -12249.27099237 -10299.27099237
#   -8349.27099237  -6399.27099237  -4449.27099237  -2499.27099237
#    -549.27099237   1400.72900763   3350.72900763   5300.72900763
#    7250.72900763   9200.72900763  11150.72900763  13100.72900763
#   15050.72900763  17000.72900763  18950.72900763  20900.72900763
#   22850.72900763  24800.72900763  26750.72900763  28700.72900763
#   30650.72900763  32600.72900763  34550.72900763  36500.72900763
#   38450.72900763  40400.72900763  42350.72900763  44300.72900763
#   46250.72900763  48200.72900763  50150.72900763  52100.72900763
#   54050.72900763  56000.72900763  57950.72900763  59900.72900763
#   61850.72900763  63800.72900763  65750.72900763  67700.72900763
#   69650.72900763  71600.72900763  73550.72900763  75500.72900763
#   77450.72900763  79400.72900763  81350.72900763  83300.72900763
#   85250.72900763  87200.72900763  89150.72900763  91100.72900763
#   93050.72900763  95000.72900763  96950.72900763  98900.72900763
#  100850.72900763 102800.72900763 104750.72900763 106700.72900763
#  108650.72900763 110600.72900763 112550.72900763 114500.72900763
#  116450.72900763 118400.72900763 120350.72900763 122300.72900763
#  124250.72900763 126200.72900763 128150.72900763 130100.72900763
#  132050.72900763 134000.72900763 135950.72900763 137900.72900763
#  139850.72900763 141800.72900763 143750.72900763 145700.72900763
#  147650.72900763 149600.72900763 151550.72900763 153500.72900763
#  155450.72900763 157400.72900763 159350.72900763 161300.72900763
#  163250.72900763 165200.72900763 167150.72900763 169100.72900763
#  171050.72900763 173000.72900763 174950.72900763 176900.72900763
#  178850.72900763]
# The value of weight at drillcollar is [-563147 -548447 -533747 -519047 -504347 -489647 -474947 -460247 -445547
#  -430847 -416147 -401447 -386747 -372047 -357347 -342647 -327947 -313247
#  -298547 -283847]

# %%
d_0 = [10000,10000,10000]

F_0 = [F_dp[0], 0 , F_dc[-1]]

# %%
plt.style.use('default')

plt.figure(figsize=(16,8))

plt.title('Axial Tensions in a Drill String as a Function of Depth')

plt.plot(F_dp,d_dp, label = 'Tension')

plt.plot(F_0,d_0, label = 'Neutral')

plt.plot(F_dc,d_dc, label = 'Compression')

plt.xlabel('Axial Stress, lbf')

plt.ylabel('Depth, ft')

plt.legend()

plt.ylim(15000,0)

plt.grid()
